# %% [markdown]
# # Name : Tofayet Sultan
# # ID : 19-40385-1
# # AI(M)
# # WEEK-11
# # Version-2

# %%
cgraph = {'WA': ['SA', 'NT'], 'Q': ['SA', 'NT', 'NSW'], 'T': [],
          'V': ['SA', 'NSW'], 'SA': ['WA', 'NT', 'Q', 'NSW','V'], 
          'NT': ['Q', 'WA', 'SA'], 
          'NSW': ['Q', 'V', 'SA']}
okColor={}

# %%
# write a method to get the highest degree node

def get_node_hd():
    mnode = ''
    length = 0
    for k in cgraph.keys():
        if(len(cgraph[k])>length and k not in okColor.keys()):
            length = len(cgraph[k])
            mnode = k
    return mnode

# %%
colorstochooselist={'WA': ['red','green', 'blue'], 
                    'Q': ['red','green', 'blue'],
                    'T': ['red', 'green', 'blue'],
                    'V':  ['red','green', 'blue'], 
                    'NT': ['red','green', 'blue'],
                    'SA': ['red','green', 'blue'],                    
                    'NSW': ['red','green', 'blue']}

import random
def get_color(node):
    # check colorstochooselist[node] is empty or not
    # return 'no color'
    if len(colorstochooselist[node])==0:
        return 0
    
    else:
        color = random.choice(colorstochooselist[node])
        colorstochooselist.pop(node)
        
        # update color options
        adjList = cgraph[node]
        for adj in adjList:
            if(adj in colorstochooselist.keys()):
                colorstochooselist[adj].remove(color)
        return color

# %%
# assign color to the highest degree node

hdNode = get_node_hd()
okColor[hdNode]= get_color(hdNode)
print(colorstochooselist)
print(okColor)
# Out:
# {'WA': ['red', 'blue'], 'Q': ['red', 'blue'], 'T': ['red', 'green', 'blue'], 'V': ['red', 'blue'], 'NT': ['red', 'blue'], 'NSW': ['red', 'blue']}
# {'SA': 'green'}

# %%
# define a method to select a node by MRV

def get_node_MRV():
    length=300
    node='x'
    for k in colorstochooselist.keys():
        if(len(colorstochooselist[k])<length):
            length = len(colorstochooselist[k])
            node = k
   

    return node

# %%
L = len(colorstochooselist)
for i in range(0,L):
    # assign color to the Minimum Remaining Value
    mrvNode = get_node_MRV()
    selected_color = get_color(mrvNode)
    if(selected_color==0):
        print('There is no soulution')
        
    else:
        # if no color returned then print failure
        okColor[hdNode]= selected_color
        print(colorstochooselist)
        print(okColor)
# Out:
# {'Q': ['red', 'blue'], 'T': ['red', 'green', 'blue'], 'V': ['red', 'blue'], 'NT': ['blue'], 'NSW': ['red', 'blue']}
# {'SA': 'red'}
# {'Q': ['red'], 'T': ['red', 'green', 'blue'], 'V': ['red', 'blue'], 'NSW': ['red', 'blue']}
# {'SA': 'blue'}
# {'T': ['red', 'green', 'blue'], 'V': ['red', 'blue'], 'NSW': ['blue']}
# {'SA': 'red'}
# {'T': ['red', 'green', 'blue'], 'V': ['red']}
# {'SA': 'blue'}
# {'T': ['red', 'green', 'blue']}
# {'SA': 'red'}
# {}
# {'SA': 'blue'}
