# %% [markdown]
# # Name:   Tofayet Sultan
# # ID:     19-40385-1
# # Course: Artificial Intelligence And Expert System
# # Section:M
# # LAB:    Week-1
# # Version:2

# %% [markdown]
# **NUMBERS**

# %%
3**2

# %%
import math
math.pi

# %%
math.sqrt(9)

# %%
import random
random.choice([11,21,31,41])

# %% [markdown]
# **STRINGS**

# %% [markdown]
# Sequence Operations

# %%
a="help"

# %%
a

# %%
len(a)

# %%
a[-1]

# %%
a[0:2]

# %%
a[1:]

# %%
a[:2]

# %%
a[:]

# %% [markdown]
# Immutibility

# %%
a+"less"

# %%
a*3

# %%
a[0]=k

# %%
a

# %% [markdown]
# Type specific methods

# %%
a.find("p")

# %%
a.replace("lp","ad")

# %%
a

# %%
a.upper()

# %%
a.lower()

# %%
aiub="American International University Bangladesh"

# %%
aiub.split(" ")

# %%
aiub.split(" ")[0]

# %%
aiub.split(" ")[-1]

# %%
pl="c++,c#,java,python,javascript,ruby,swift"

# %%
pl.split(",")

# %%
pl.split(",")[0]

# %%
aiub

# %%
aiub.isdigit()

# %%
aiub.rstrip()

# %%
c=" color "

# %%
c.lstrip()

# %%
dir(aiub)

# %%
d="ab\ncd"

# %%
len(d)

# %%
e="""ab
cd
ef"""

# %%
e

# %% [markdown]
# **LISTS**

# %%
g=[3,'orange','and',2]

# %%
g[0]

# %%
g+['band']

# %%
g

# %%
g.append('band')

# %%
g

# %%
g.pop(0)

# %%
g

# %%
g.reverse()

# %%
g

# %%
g.pop(1)

# %%
g.sort()

# %%
g

# %% [markdown]
# **Nesting**

# %%
m=[1,2,3],[2,3,1],[5,6,4]

# %%
m

# %%
m[2]

# %%
m[2][2]

# %%
colom = [row[1] for row in m] 
colom
# Out:
# [2, 3, 6]

# %% [markdown]
# **DICTIONARIES**

# %%
 student= {'name': 'Tofayet sultan', 'age': 22, 'dept': 'CSE'}

# %%
student

# %%
student['name']

# %%
student['age']+=1

# %%
student

# %%
 Student = {} 
Student['name'] = 'Tofayet sultan' 
Student['age']  = 22
Student['dept']='cse'

# %%
Student

# %% [markdown]
# **Nesting revisited**

# %%
details={'name':{'firstName':'Tofayet','lastName':'Sultan'},
         'job':['student','Semester-7'],
         'age':23
    
}

# %%
details['name']
# Out:
# {'firstName': 'Tofayet', 'lastName': 'Sultan'}

# %%
details['job']

# %%
details['name']['lastName']
# Out:
# 'Sultan'

# %%
details['job'].append('Courses-30')

# %%
details
# Out:
# {'name': {'firstName': 'Tofayet', 'lastName': 'Sultan'},
#  'job': ['student', 'Semester-7', 'Courses-30'],
#  'age': 23}

# %%
details=0

# %%
details
# Out:
# 0

# %%
numbers={'a':1,'c':2,'b':3}

# %%
numbers
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
numbers.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
for key in numbers:
  print (key, '=>', numbers[key])
# Out:
# a => 1
# c => 2
# b => 3

# %%
for key in sorted(numbers):
    print(key,'=>',numbers[key])
# Out:
# a => 1
# b => 3
# c => 2

# %%
for c in 'floccinaucinihilipilification':
    print(c)
# Out:
# f
# l
# o
# c
# c
# i
# n
# a
# u
# c
# i
# n
# i
# h
# i
# l
# i
# p
# i
# l
# i
# f
# i
# c
# a
# t
# i
# o
# n

# %%
squares=[x**2 for x in[2,9,6,8] ]

# %%
squares
# Out:
# [4, 81, 36, 64]

# %%
sorted(squares)
# Out:
# [4, 36, 64, 81]

# %%
Squares=[]
for x in[2,9,6,8]:
    Squares.append(x**2)

# %%
Squares
# Out:
# [4, 81, 36, 64]

# %%
D={'a':1,'c':2,'b':3}

# %%
D['e']=4

# %%
D
# Out:
# {'a': 1, 'c': 2, 'b': 3, 'e': 4}

# %% [markdown]
# **Tuples**

# %%
t=(2,4,3,2)

# %%
t
# Out:
# (2, 4, 3, 2)

# %%
t+(3,4)
# Out:
# (2, 4, 3, 2, 3, 4)

# %%
t[2]
# Out:
# 3

# %% [markdown]
# Files

# %%
m = open('data.txt', 'w') 
m.write('Artificial\n')
m.write('Intelligence\n')
m.close()

# %%
m=open('data.txt')
bytes=m.read()
print(bytes)
# Out:
# Artificial
# Intelligence

# %%
bytes.split()
# Out:
# ['Artificial', 'Intelligence']

# %% [markdown]
# Other core types

# %%
i=set('banged')
j=set(['b','n','a'])
i,j
# Out:
# ({'a', 'b', 'd', 'e', 'g', 'n'}, {'a', 'b', 'n'})

# %%
i&j
# Out:
# {'a', 'b', 'n'}

# %%
i|j
# Out:
# {'a', 'b', 'd', 'e', 'g', 'n'}

# %%
i-j
# Out:
# {'d', 'e', 'g'}

# %%
 import decimal
d = decimal.Decimal('3.141')
d + 1
# Out:
# Decimal('4.141')

# %%
2>3
# Out:
# False

# %%
 class Worker: 
    def __init__(self, name,salary): 
            self.name = name 
            self.salary  = salary
    def firstName(self): 
     return self.name.split()[0] 
    def increase(self, add): 
     self.pay *= (1.0 + add)

# %%
sundar = Worker('Sundar pichai', 50000) 
sundar.firstName()
# Out:
# 'Sundar'

# %%
def myself():
    print("Tofayet sultan")
    print("19-40385-1")
    print("Dept:CSE")
    print("Semester:7th")
    
myself()
# Out:
# Tofayet sultan
# 19-40385-1
# Dept:CSE
# Semester:7th

# %% [markdown]
# Function

# %%
import math
def root(value):
    print(math.sqrt(value))
def pi():
    print(math.pi)    
    
root(4)
pi()
# Out:
# 2.0
