# %% [markdown]
# # Name: Tofayet Sultan
# # ID: 19-40385-1
# # Course: Artificial Intelligence And Expert System
# # Section:M
# # LAB: Week-2(Lesson-3,5)
# # Version:2

# %%
def get_names(full_name):
    p=full_name.split()
    return p[0],p[1:-1],p[-1]

# %%
get_names("MD Tofayet Sultan Neon")

# %% [markdown]
# *Lesson-3*

# %% [markdown]
# **Lists**

# %%
len([9,10,11,12])

# %%
[1,200]+[0,1,-2]

# %%
['Neon']*5

# %%
-2 in [-3,-1,0,-4]

# %%
for x in [10,20,'a']:
    print(x)

# %%
str([3,-1,0])+"a"

# %%
[3,-1,0]+list("a")

# %%
a=['and','And','AND']

# %%
a[-2]

# %%
a[:-1]

# %%
a[0:]

# %%
m=[10,20,'a'],[40,50,60],[70,80,90]

# %%
m[0]

# %%
m[0][2]

# %%
a[1]='or'

# %%
a

# %%
a[1:]

# %%
a.append('OR')

# %%
a

# %%
a.sort()

# %%
a

# %%
a.extend(['end','END'])

# %%
a.pop()

# %%
a.reverse()

# %%
a

# %%
a=[]

# %%
a.append('a')

# %%
a.append('b')

# %%
a

# %%
a.pop()

# %%
a

# %%
a.extend(['b','c','d'])

# %%
del a[3]

# %%
del a[1:]

# %%
a=[1,2,3,4,5]

# %%
a[2:]=[]

# %%
a

# %% [markdown]
# **Dictionaries**

# %%
b={'c':-1,'d':1,'e':0}

# %%
b['c']

# %%
len(b)

# %%
'd'in b.keys()

# %%
b.keys()

# %%
b['c']=[0,1]

# %%
b

# %%
del b['d']

# %%
b['f']=2

# %%
b.values()

# %%
b.items()

# %%
b.get('c')

# %%
b.get('g',2)

# %%
c={'g':10,'h':11}

# %%
b.update(c)

# %%
b.pop('h')

# %%
c=['a','b','c']

# %%
c.pop(2)

# %%
c.pop()

# %%
c

# %%
pl={'Java':'James Gosling','C':'Denis Ritchie','Python':'Guido Van Rossum'}

# %%
language='Java'

# %%
creator=pl[language]

# %%
creator

# %%
for x in pl.keys():
    print(x,'\t',pl[x])

# %%
d={}

# %%
d[11]="and"

# %%
d[11]

# %%
d

# %%
m={}

# %%
m[(2,4,6)]=-1

# %%
m[(3,6,9)]=0

# %%
n=3;o=6;p=9

# %%
m[(n,o,p)]

# %%
m

# %%
if (2,4,6) in m:
    print('a')
else:
    print('b')

# %%
m.get((2,4,6),0)

# %%
r={}
r['name']='Dip Imam'
r['age']=22
r['cgpa']='3.93'

# %%
r['cgpa']

# %%
profile={'name':'Fazle imam dip',
         'job':['Software engineer','Project leader'],
         'website':'www.dipimam.com',
         'home':{'district':'Pabna','division':'Rajshahi'}}

# %%
profile['job']

# %%
profile['job'][0]

# %%
profile['home']['division']

# %% [markdown]
# *Lesson-5*

# %%
a=10;b=5;print(a+b)

# %%
while True:
    reply=input('Enter text:')
    if reply=='stop':break
    print(reply.upper( ))

# %%
while True:
    reply=input('Enter text:')
    if reply=='stop':break
    print(int(reply)**2)

# %%
s='2345'
t='and'
s.isdigit(),t.isdigit()

# %%
while True:
    reply=input('Enter whatever you want:')
    if reply=='stop':
        break
    elif not reply.isdigit():
        print('not a digit \t'*2)
    else:
        print(int(reply)**2)        
print('End')

# %%
while True:
    reply=input('Enter whatever you want:')
    if reply=='stop':break
    try:
        num=int(reply)
    except:
        print('not a digit\t'*2)
    else:
        print(int(reply)**2)        
print('End')

# %%
while True:
    reply=input('Whats on your mind:')
    if reply=='finish':
        break
    elif not reply.isdigit():
        print('Its not a digit')
    else:
        temp=int(reply)
        if temp> 10:
            print(temp**2)
        else:
            print(temp)
